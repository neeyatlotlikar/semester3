# %% [markdown]
# Gradient Descent

# %%
class GradientDescent:
    def __init__(self, learning_rate=0.01, max_iterations=1000):
        self.learning_rate = learning_rate
        self.max_iterations = max_iterations

    def optimize(self, loss_function, gradient_function, initial_params):
        params = initial_params
        history = []
        for i in range(self.max_iterations):
            gradients = gradient_function(params)
            params -= self.learning_rate * gradients

            if i % 100 == 0:  # Print status every 100 iterations
                loss = loss_function(params)
                print(f"Iteration {i}: Loss = {loss}, Params = {params}")
                history.append((i, loss))
        return params, history

# %% [markdown]
# Example 1: Gradient Descent applied to a simple quadratic function and plotted

# %%
# Example loss function
def loss_function(x):
    return (x - 3) ** 2


# Example gradient function (derivative of the loss function)
def gradient_function(x):
    return 2 * (x - 3)


# Starting point for optimization
initial_params = 0

# Example usage of the GradientDescent class
gd = GradientDescent(learning_rate=0.01, max_iterations=500)

# Any differentiable function and its gradient can be supplied
final_params, history = gd.optimize(loss_function, gradient_function, initial_params)

print(f"Final parameters: {final_params}")
print(f"Final loss: {loss_function(final_params)}")
# Out:
# Iteration 0: Loss = 8.6436, Params = 0.06
# Iteration 100: Loss = 0.15202317528121487, Params = 2.6100985056694257
# Iteration 200: Loss = 0.002673775489678234, Params = 2.948291436979179
# Iteration 300: Loss = 4.7026220548144296e-05, Params = 2.993142433336223
# Iteration 400: Loss = 8.270946560695898e-07, Params = 2.9990905525545313
# Final parameters: 2.9998769280445634
# Final loss: 1.5146706214986814e-08

# %%
import matplotlib.pyplot as plt

# Plot a graph of the loss over iterations
iterations, losses = zip(*history)

plt.figure(figsize=(10, 5))
plt.plot(iterations, losses)
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.title("Loss over Iterations")
plt.show()

# %% [markdown]
# Example 2: Gradient Descent applied to a higher order function and plotted

# %%
# Example of a complex loss function
def complex_loss_function(x):
    return (x - 2) ** 2 + 5 * (x - 1) ** 4


# Example gradient function (derivative of the loss function)
def gradient_function(x):
    return 2 * (x - 2) + 20 * (x - 1) ** 3


# Starting point for optimization
initial_params = 0

# Example usage of the GradientDescent class
gd = GradientDescent(learning_rate=0.01, max_iterations=500)

# Any differentiable function and its gradient can be supplied
final_params, history = gd.optimize(loss_function, gradient_function, initial_params)

print(f"Final parameters: {final_params}")
print(f"Final loss: {loss_function(final_params)}")
# Out:
# Iteration 0: Loss = 7.617599999999999, Params = 0.24
# Iteration 100: Loss = 2.582711358941614, Params = 1.3929183720353175
# Iteration 200: Loss = 2.5824401986993335, Params = 1.3930027384281785
# Iteration 300: Loss = 2.582440196954381, Params = 1.3930027389711017
# Iteration 400: Loss = 2.5824401969543724, Params = 1.3930027389711044
# Final parameters: 1.3930027389711044
# Final loss: 2.5824401969543724

# %%
import matplotlib.pyplot as plt

# Plot a graph of the loss over iterations
iterations, losses = zip(*history)

plt.figure(figsize=(10, 5))
plt.plot(iterations, losses)
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.title("Loss over Iterations")
plt.show()

# %% [markdown]
# Example 3: Gradient Descent applied to a Multivariate function and plotted

# %%
class MultivariateGradientDescent:
    def __init__(self, learning_rate=0.01, max_iterations=1000):
        self.learning_rate = learning_rate
        self.max_iterations = max_iterations

    def optimize(self, loss_function, gradient_function, initial_params):
        params = initial_params
        history = []
        for i in range(self.max_iterations):
            gradients = gradient_function(params)
            params = [p - self.learning_rate * g for p, g in zip(params, gradients)]

            if i % 100 == 0:  # Print status every 100 iterations
                loss = loss_function(params)
                print(f"Iteration {i}: Loss = {loss}, Params = {params}")
                history.append((i, loss))
        return params, history

# %%
# Example of a multivariate loss function
def multivariate_loss_function(x):
    return (x[0] - 1) ** 2 + (x[1] - 2) ** 2 + (x[0] - x[1]) ** 2


# Example of a multivariate gradient function (derivative of the loss function)
def gradient_function(x):
    return [2 * (x[0] - 1) + 2 * (x[0] - x[1]), 2 * (x[1] - 2) - 2 * (x[0] - x[1])]


# Starting point for optimization
initial_params = [0, 0]

# Example usage of the GradientDescent class
gd = MultivariateGradientDescent(learning_rate=0.01, max_iterations=500)

# Any differentiable function and its gradient can be supplied
final_params, history = gd.optimize(
    multivariate_loss_function, gradient_function, initial_params
)

print(f"Final parameters: {final_params}")
print(f"Final loss: {multivariate_loss_function(final_params)}")
# Out:
# Iteration 0: Loss = 4.8024, Params = [0.02, 0.04]
# Iteration 100: Loss = 0.40934554280896057, Params = [1.138704516548762, 1.4713939891206647]
# Iteration 200: Loss = 0.33467022108079814, Params = [1.3074797133495402, 1.6408117236296387]
# Iteration 300: Loss = 0.3333568464436074, Params = [1.3299045513607992, 1.6632378819754234]
# Iteration 400: Loss = 0.33333374688066136, Params = [1.332878609613392, 1.666211942941139]
# Final parameters: [1.3332717973556214, 1.666605130688942]
# Final loss: 0.3333333409066864

# %%
import matplotlib.pyplot as plt

# Plot a graph of the loss over iterations
iterations, losses = zip(*history)

plt.figure(figsize=(10, 5))
plt.plot(iterations, losses)
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.title("Loss over Iterations")
plt.show()
